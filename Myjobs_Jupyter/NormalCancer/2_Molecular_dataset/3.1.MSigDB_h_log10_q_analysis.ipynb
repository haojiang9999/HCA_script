# %%
#### 1.Loading_data.R
COAD.tb.h.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.h.log10.q.all.rds")
COAD.tb.c1.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.c1.log10.q.all.rds")
COAD.tb.c2.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.c2.log10.q.all.rds")
COAD.tb.c3.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.c3.log10.q.all.rds")
COAD.tb.c4.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.c4.log10.q.all.rds")
COAD.tb.c5.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.c5.log10.q.all.rds")
COAD.tb.c6.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.c6.log10.q.all.rds")
COAD.tb.c7.log10.q.all <- readRDS("/data8t_4/JH/MyJobs/COAD_NormalCancer_Project/2.Molecular_dataset/2.Gene_set_analysis/COAD.tb.c7.log10.q.all.rds")

# %%
#### 2.1.MSigDB_h_log10_q_analysis.R
#COAD.tb.h.log10.q.all
library(reshape2)
library(ggplot2)
h.log10.q.all.m <- melt(COAD.tb.h.log10.q.all)
options(repr.plot.width=10, repr.plot.height=20)
ggplot(h.log10.q.all.m, aes(Var2, Var1)) +
  geom_tile(aes(fill = value),colour = "black") + 
  theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
  scale_fill_gradient2(low = "mediumblue", high = "red2", mid = "white",midpoint = 0) + coord_fixed()
# Out:
# plot without title
